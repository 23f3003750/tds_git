# %%
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Kaggle credentials successfully validated.

# %%
jan_2026_dl_gen_ai_project_path = kagglehub.competition_download('jan-2026-dl-gen-ai-project')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/jan-2026-dl-gen-ai-project...
# 100%|██████████| 16.1G/16.1G [03:03<00:00, 94.2MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# ## Q.1

# %%
import torch
x=torch.randn(32,1,64,64)
x_flat=x.view(x.size(0),-1)
x_flat.shape[1]
# Out:
# 4096

# %% [markdown]
# ## Q.2

# %%
import torchaudio


sample_rate = 16000
duration = 1  # seconds
n_fft = 400
hop_length = 160
n_mels = 64


waveform = torch.randn(1, sample_rate * duration)


print("Waveform shape:", waveform.shape)


mel_transform = torchaudio.transforms.MelSpectrogram(
    sample_rate=sample_rate,
    n_fft=n_fft,
    hop_length=hop_length,
    n_mels=n_mels
)


mel_spec = mel_transform(waveform)

print("Mel Spectrogram shape:", mel_spec.shape)
# Out:
# Waveform shape: torch.Size([1, 16000])
# Mel Spectrogram shape: torch.Size([1, 64, 101])

# %% [markdown]
# ## Q.3

# %%
import torch
import torch.nn as nn


x = torch.randn(1, 1, 64, 64)

conv = nn.Conv2d(
    in_channels=1,
    out_channels=8,
    kernel_size=3,
    stride=1,
    padding=1
)

pool = nn.MaxPool2d(
    kernel_size=2,
    stride=2
)


x = conv(x)
print("After Conv:", x.shape)

x = pool(x)
print("After MaxPool:", x.shape)
# Out:
# After Conv: torch.Size([1, 8, 64, 64])
# After MaxPool: torch.Size([1, 8, 32, 32])

# %% [markdown]
# ## Q.4

# %%
import torch
import torch.nn as nn


layer = nn.Linear(in_features=128, out_features=64)


total_params = 0
for param in layer.parameters():
    total_params += param.numel()

print("Total parameters:", total_params)
# Out:
# Total parameters: 8256

# %% [markdown]
# ## Q.5

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset


data = torch.randn(1050, 10)
dataset = TensorDataset(data)

loader = DataLoader(dataset, batch_size=32, drop_last=False)

print("Number of batches:", len(loader))
# Out:
# Number of batches: 33

# %% [markdown]
# ## Q.6

# %%
import torch
import torch.nn as nn


logits = torch.tensor([[2.5, 1.0, 0.1]])


target = torch.tensor([0])


criterion = nn.CrossEntropyLoss()

loss = criterion(logits, target)

print("Loss:", round(loss.item(), 3))
# Out:
# Loss: 0.273

# %% [markdown]
# ### Q.7

# %%
import torch


w = torch.tensor([0.5], requires_grad=True)


w.grad = torch.tensor([0.2])


optimizer = torch.optim.SGD([w], lr=0.01)


optimizer.step()

print("Updated weight:", w.item())
# Out:
# Updated weight: 0.49799999594688416

# %% [markdown]
# ### Q.8

# %%
import torch
import torch.nn as nn

x = torch.randn(1, 1, 64, 64)

conv = nn.Conv2d(
    in_channels=1,
    out_channels=8,
    kernel_size=5,
    stride=1,
    padding=2
)

y = conv(x)

print("Input shape:", x.shape)
print("Output shape:", y.shape)
# Out:
# Input shape: torch.Size([1, 1, 64, 64])
# Output shape: torch.Size([1, 8, 64, 64])

# %% [markdown]
# ## Q.9

# %%
import wandb

# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: n22031020 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import wandb
import random


wandb.init(project="simple-milestone-3-demo",entity="n22031020-indian-institute-of-technology-madras")


for epoch in range(5):
    loss = random.random()
    accuracy = random.random()


    # Answer-9
    wandb.log({
        "loss": loss,
        "accuracy": accuracy
    })



    print(f"Epoch {epoch}: loss={loss:.3f}, acc={accuracy:.3f}")

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260301_095106-vhcnns41</code>
# Syncing run <strong><a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo/runs/vhcnns41' target="_blank">worldly-rain-1</a></strong> to <a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo' target="_blank">https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo</a>
#  View run at <a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo/runs/vhcnns41' target="_blank">https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo/runs/vhcnns41</a>
# Epoch 0: loss=0.427, acc=0.813
# Epoch 1: loss=0.891, acc=0.912
# Epoch 2: loss=0.425, acc=0.775
# Epoch 3: loss=0.203, acc=0.043
# Epoch 4: loss=0.129, acc=0.506
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▇█▇▁▅</td></tr><tr><td>loss</td><td>▄█▄▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.50627</td></tr><tr><td>loss</td><td>0.12928</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-rain-1</strong> at: <a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo/runs/vhcnns41' target="_blank">https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo/runs/vhcnns41</a><br> View project at: <a href='https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo' target="_blank">https://wandb.ai/n22031020-indian-institute-of-technology-madras/simple-milestone-3-demo</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260301_095106-vhcnns41/logs</code>

# %% [markdown]
# ### Q.10

# %%
correct = 170
total = 200

accuracy = correct / total

print("Accuracy:", accuracy)
print("Accuracy (%):", accuracy * 100)
# Out:
# Accuracy: 0.85
# Accuracy (%): 85.0
